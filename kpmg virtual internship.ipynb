# %%
# pip install -U scikit-learn

# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
import warnings
warnings.filterwarnings('ignore')

# %%
df=pd.read_excel('KPMG _data (1).xlsx',sheet_name='Transactions')

# %%
df1=pd.read_excel('KPMG _data (1).xlsx',sheet_name='NewCustomerList')

# %%
df2=pd.read_excel('KPMG _data (1).xlsx',sheet_name='CustomerDemographic')

# %%
df3=pd.read_excel('KPMG _data (1).xlsx',sheet_name='CustomerAddress')

# %%
df1.head(2),df2.head(2),df3.head(2)
# Out:
# (  first_name last_name gender  past_3_years_bike_related_purchases        DOB  \
#  0        NaN       NaN    NaN                                  NaN        NaT
#  1    Chickie   Brister   Male                                 86.0 1957-07-12
#
#           job_title job_industry_category wealth_segment deceased_indicator  \
#  0              NaN                   NaN            NaN                NaN
#  1  General Manager         Manufacturing  Mass Customer                  N
#
#    owns_car  ...  state    country  property_valuation Unnamed: 16 Unnamed: 17  \
#  0      NaN  ...    NaN        NaN                 NaN         NaN         NaN
#  1      Yes  ...    QLD  Australia                 6.0        0.42       0.525
#
#     Unnamed: 18  Unnamed: 19  Unnamed: 20  Rank    Value
#  0          NaN          NaN          NaN   NaN      NaN
#  1      0.65625     0.557812          1.0   1.0  1.71875
#
#  [2 rows x 23 columns],    customer_id first_name  last_name gender  \
# ...

# %%
df.head()
# Out:
#    transaction_id  product_id  customer_id transaction_date  online_order  \
# 0             NaN         NaN          NaN              NaT           NaN
# 1             1.0         2.0       2950.0       2017-02-25           0.0
# 2             2.0         3.0       3120.0       2017-05-21           1.0
# 3             3.0        37.0        402.0       2017-10-16           0.0
# 4             4.0        88.0       3135.0       2017-08-31           0.0
#
#   order_status           brand product_line product_class product_size  \
# 0          NaN             NaN          NaN           NaN          NaN
# 1     Approved           Solex     Standard        medium       medium
# 2     Approved   Trek Bicycles     Standard        medium        large
# 3     Approved      OHM Cycles     Standard           low       medium
# 4     Approved  Norco Bicycles     Standard        medium       medium
#
#    list_price  standard_cost  product_first_sold_date
# ...

# %%
df.drop(df.index[0],inplace=True)

# %%
df.head()
# Out:
#    transaction_id  product_id  customer_id transaction_date  online_order  \
# 1             1.0         2.0       2950.0       2017-02-25           0.0
# 2             2.0         3.0       3120.0       2017-05-21           1.0
# 3             3.0        37.0        402.0       2017-10-16           0.0
# 4             4.0        88.0       3135.0       2017-08-31           0.0
# 5             5.0        78.0        787.0       2017-10-01           1.0
#
#   order_status           brand product_line product_class product_size  \
# 1     Approved           Solex     Standard        medium       medium
# 2     Approved   Trek Bicycles     Standard        medium        large
# 3     Approved      OHM Cycles     Standard           low       medium
# 4     Approved  Norco Bicycles     Standard        medium       medium
# 5     Approved  Giant Bicycles     Standard        medium        large
#
#    list_price  standard_cost  product_first_sold_date
# ...

# %%
df1.drop(df1.index[0],inplace=True)
df2.drop(df2.index[0],inplace=True)
df3.drop(df3.index[0],inplace=True)

# %%
df1.head(2)
# Out:
#   first_name last_name gender  past_3_years_bike_related_purchases        DOB  \
# 1    Chickie   Brister   Male                                 86.0 1957-07-12
# 2      Morly    Genery   Male                                 69.0 1970-03-22
#
#              job_title job_industry_category wealth_segment  \
# 1      General Manager         Manufacturing  Mass Customer
# 2  Structural Engineer              Property  Mass Customer
#
#   deceased_indicator owns_car  ...  state    country  property_valuation  \
# 1                  N      Yes  ...    QLD  Australia                 6.0
# 2                  N       No  ...    NSW  Australia                11.0
#
#   Unnamed: 16 Unnamed: 17  Unnamed: 18  Unnamed: 19  Unnamed: 20  Rank  \
# 1        0.42       0.525      0.65625     0.557812          1.0   1.0
# 2        0.47       0.470      0.58750     0.499375          1.0   1.0
#
#      Value
# 1  1.71875
# 2  1.71875
#
# [2 rows x 23 columns]

# %%
df1.drop(['Unnamed: 16','Unnamed: 17','Unnamed: 18','Unnamed: 19','Unnamed: 20'],axis=1,inplace=True)

# %%
df1.head(2)
# Out:
#   first_name last_name gender  past_3_years_bike_related_purchases        DOB  \
# 1    Chickie   Brister   Male                                 86.0 1957-07-12
# 2      Morly    Genery   Male                                 69.0 1970-03-22
#
#              job_title job_industry_category wealth_segment  \
# 1      General Manager         Manufacturing  Mass Customer
# 2  Structural Engineer              Property  Mass Customer
#
#   deceased_indicator owns_car  tenure            address  postcode state  \
# 1                  N      Yes    14.0   45 Shopko Center    4500.0   QLD
# 2                  N       No    16.0  14 Mccormick Park    2113.0   NSW
#
#      country  property_valuation  Rank    Value
# 1  Australia                 6.0   1.0  1.71875
# 2  Australia                11.0   1.0  1.71875

# %%
df2.head(2)
# Out:
#    customer_id first_name  last_name gender  \
# 1          1.0    Laraine  Medendorp      F
# 2          2.0        Eli    Bockman   Male
#
#    past_3_years_bike_related_purchases        DOB               job_title  \
# 1                                 93.0 1953-10-12     Executive Secretary
# 2                                 81.0 1980-12-16  Administrative Officer
#
#   job_industry_category wealth_segment deceased_indicator  \
# 1                Health  Mass Customer                  N
# 2    Financial Services  Mass Customer                  N
#
#                         default owns_car  tenure
# 1                            "'      Yes    11.0
# 2  <script>alert('hi')</script>      Yes    16.0

# %%
df3.head(2)
# Out:
#    customer_id              address  postcode            state    country  \
# 1          1.0   060 Morning Avenue    2016.0  New South Wales  Australia
# 2          2.0  6 Meadow Vale Court    2153.0  New South Wales  Australia
#
#    property_valuation
# 1                10.0
# 2                10.0

# %% [markdown]
# ## Checking missing values:

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 20000 entries, 1 to 20000
# Data columns (total 13 columns):
# transaction_id             20000 non-null float64
# product_id                 20000 non-null float64
# customer_id                20000 non-null float64
# transaction_date           20000 non-null datetime64[ns]
# online_order               19640 non-null float64
# order_status               20000 non-null object
# brand                      19803 non-null object
# product_line               19803 non-null object
# product_class              19803 non-null object
# product_size               19803 non-null object
# list_price                 20000 non-null float64
# standard_cost              19803 non-null float64
# product_first_sold_date    19803 non-null float64
# dtypes: datetime64[ns](1), float64(7), object(5)
# memory usage: 2.1+ MB

# %%
df.isnull().sum()/len(df)*100
# Out:
# transaction_id             0.000
# product_id                 0.000
# customer_id                0.000
# transaction_date           0.000
# online_order               1.800
# order_status               0.000
# brand                      0.985
# product_line               0.985
# product_class              0.985
# product_size               0.985
# list_price                 0.000
# standard_cost              0.985
# product_first_sold_date    0.985
# dtype: float64

# %%
col=['transaction_id', 'product_id', 'customer_id', 'transaction_date',
       'online_order', 'order_status', 'brand', 'product_line',
       'product_class', 'product_size', 'list_price', 'standard_cost',
       'product_first_sold_date']
for i in col:
    print(i,'\n',df[i].unique(),'\n','No of unique value:',df[i].nunique(),'\n')
# Out:
# transaction_id
#  [1.0000e+00 2.0000e+00 3.0000e+00 ... 1.9998e+04 1.9999e+04 2.0000e+04]
#  No of unique value: 20000
#
# product_id
#  [  2.   3.  37.  88.  78.  25.  22.  15.  67.  12.   5.  61.  35.  16.
#   79.  33.  54.  27.  82.  89.  64.  19.  72.  91.   1.  99.   0.  92.
#   14.  44.  76.  46.  55.  66.  81.  86.  32.  77.  96.   6.  47.  94.
#   93.  60.  28.   4.  38.  56.  58.  50.  80.  87.  84.  21.  31.  62.
#   17.  73.  45.  49.  95.  18.  70.  26.  39.  36.  98.  75.  42.  20.
#   24.  53.  65.  29.  11.  10.   7.  41.   9.  69.  90.  97. 100.  74.
#   71.  34.  57.  23.  51.  59.  63.  40.   8.  13.  30.  48.  68.  83.
#   43.  52.  85.]
#  No of unique value: 101
#
# customer_id
#  [2950. 3120.  402. ...  130. 2789. 3446.]
#  No of unique value: 3494
#
# transaction_date
#  ['2017-02-25T00:00:00.000000000' '2017-05-21T00:00:00.000000000'
#  '2017-10-16T00:00:00.000000000' '2017-08-31T00:00:00.000000000'
# ...

# %%
df1.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 1000 entries, 1 to 1000
# Data columns (total 18 columns):
# first_name                             1000 non-null object
# last_name                              971 non-null object
# gender                                 1000 non-null object
# past_3_years_bike_related_purchases    1000 non-null float64
# DOB                                    983 non-null datetime64[ns]
# job_title                              894 non-null object
# job_industry_category                  835 non-null object
# wealth_segment                         1000 non-null object
# deceased_indicator                     1000 non-null object
# owns_car                               1000 non-null object
# tenure                                 1000 non-null float64
# address                                1000 non-null object
# postcode                               1000 non-null float64
# state                                  1000 non-null object
# ...

# %%
df1.isnull().sum()/len(df1)*100
# Out:
# first_name                              0.0
# last_name                               2.9
# gender                                  0.0
# past_3_years_bike_related_purchases     0.0
# DOB                                     1.7
# job_title                              10.6
# job_industry_category                  16.5
# wealth_segment                          0.0
# deceased_indicator                      0.0
# owns_car                                0.0
# tenure                                  0.0
# address                                 0.0
# postcode                                0.0
# state                                   0.0
# country                                 0.0
# property_valuation                      0.0
# Rank                                    0.0
# Value                                   0.0
# dtype: float64

# %%
col1=['first_name', 'last_name', 'gender',
       'past_3_years_bike_related_purchases', 'DOB', 'job_title',
       'job_industry_category', 'wealth_segment', 'deceased_indicator',
       'owns_car', 'tenure', 'address', 'postcode', 'state', 'country',
       'property_valuation', 'Rank', 'Value']
for i in col1:
    print(i,'\n',df1[i].unique(),'\n','No of unique value:',df1[i].nunique(),'\n')
# Out:
# first_name
#  ['Chickie' 'Morly' 'Ardelis' 'Lucine' 'Melinda' 'Druci' 'Rutledge'
#  'Nancie' 'Duff' 'Barthel' 'Rockwell' 'Wheeler' 'Olag' 'Melba' 'Mandie'
#  'Dukie' 'Marcelia' 'Winnifred' 'Odilia' 'Karly' 'Teddie' 'Gaston' 'Otis'
#  'Tabbatha' 'Brena' 'Rourke' 'Dyane' 'Claudine' 'Blinnie' 'Rhona'
#  'Sharron' 'Brien' 'Sybilla' 'Mikel' 'Maisie' 'Arleen' 'Farlie' 'Mitchell'
#  'Garik' 'Antonin' 'Vinny' 'Colene' 'Neile' 'Corinna' 'Brooke' 'Gipsy'
#  'Sheena' 'Jobina' 'Gale' 'Thaxter' 'Heinrick' 'Taylor' 'Griswold'
#  'Odessa' 'Lavena' 'Martelle' 'Briant' 'Marylou' 'Whittaker' 'Normy'
#  'Lorrie' 'Jedediah' 'Kaine' 'Loise' 'Cristen' 'Dorothy' 'Rosmunda'
#  'Rozamond' 'Gunner' 'Vivienne' 'Sherilyn' 'Bessie' 'Kevina' 'Yancy'
#  'Mabelle' 'Hasheem' 'Tobias' 'Glennis' 'Chanda' 'Katheryn' 'Sumner'
#  'Valerie' 'Esther' 'Gardie' 'Sean' 'Pietra' 'Marysa' 'Kahaleel' 'Ossie'
#  'Sid' 'Ludovico' 'Patricia' 'Andromache' 'Levy' 'Nobe' 'Jehu' 'Symon'
# ...

# %%
df2.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 4000 entries, 1 to 4000
# Data columns (total 13 columns):
# customer_id                            4000 non-null float64
# first_name                             4000 non-null object
# last_name                              3875 non-null object
# gender                                 4000 non-null object
# past_3_years_bike_related_purchases    4000 non-null float64
# DOB                                    3913 non-null datetime64[ns]
# job_title                              3494 non-null object
# job_industry_category                  3344 non-null object
# wealth_segment                         4000 non-null object
# deceased_indicator                     4000 non-null object
# default                                3698 non-null object
# owns_car                               4000 non-null object
# tenure                                 3913 non-null float64
# dtypes: datetime64[ns](1), float64(3), object(9)
# ...

# %%
df2.isnull().sum()/len(df2)*100
# Out:
# customer_id                             0.000
# first_name                              0.000
# last_name                               3.125
# gender                                  0.000
# past_3_years_bike_related_purchases     0.000
# DOB                                     2.175
# job_title                              12.650
# job_industry_category                  16.400
# wealth_segment                          0.000
# deceased_indicator                      0.000
# default                                 7.550
# owns_car                                0.000
# tenure                                  2.175
# dtype: float64

# %%
col2=['customer_id', 'first_name', 'last_name', 'gender',
       'past_3_years_bike_related_purchases', 'DOB', 'job_title',
       'job_industry_category', 'wealth_segment', 'deceased_indicator',
       'default', 'owns_car', 'tenure']
for i in col2:
    print(i,'\n',df2[i].unique(),'\n','No of unique value:',df2[i].nunique(),'\n')
# Out:
# customer_id
#  [1.000e+00 2.000e+00 3.000e+00 ... 3.998e+03 3.999e+03 4.000e+03]
#  No of unique value: 4000
#
# first_name
#  ['Laraine' 'Eli' 'Arlin' ... 'Stephie' 'Rusty' 'Sarene']
#  No of unique value: 3139
#
# last_name
#  ['Medendorp' 'Bockman' 'Dearle' ... 'Halgarth' 'Woolley' 'Oldland']
#  No of unique value: 3725
#
# gender
#  ['F' 'Male' 'Female' 'U' 'Femal' 'M']
#  No of unique value: 6
#
# past_3_years_bike_related_purchases
#  [93. 81. 61. 33. 56. 35.  6. 31. 97. 49. 99. 58. 38. 85. 91. 57. 79. 76.
#  72. 74. 43. 55. 12. 37.  5. 62. 18.  3. 17. 44. 59. 40. 46. 64. 24. 63.
#  98. 51. 68. 22.  2. 48. 87. 26. 60. 47. 73. 21. 67. 16. 78. 30. 94. 28.
#  20. 11.  1. 75. 41. 69. 19. 80. 83. 25. 54.  4. 23. 65. 88. 10. 77.  9.
#  82. 27. 53. 32. 34. 71. 36. 90. 95.  8. 39.  7. 42. 13. 45. 50. 14. 89.
#  84. 96. 70. 66.  0. 15. 86. 92. 29. 52.]
#  No of unique value: 100
#
# DOB
#  ['1953-10-12T00:00:00.000000000' '1980-12-16T00:00:00.000000000'
# ...

# %%
df3.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 3999 entries, 1 to 3999
# Data columns (total 6 columns):
# customer_id           3999 non-null float64
# address               3999 non-null object
# postcode              3999 non-null float64
# state                 3999 non-null object
# country               3999 non-null object
# property_valuation    3999 non-null float64
# dtypes: float64(3), object(3)
# memory usage: 218.7+ KB

# %%
df3.isnull().sum()/len(df3)*100
# Out:
# customer_id           0.0
# address               0.0
# postcode              0.0
# state                 0.0
# country               0.0
# property_valuation    0.0
# dtype: float64

# %%
col3=['customer_id', 'address', 'postcode', 'state', 'country',
       'property_valuation']
for i in col3:
    print(i,'\n',df3[i].unique(),'\n','No of unique value:',df3[i].nunique(),'\n')
# Out:
# customer_id
#  [1.000e+00 2.000e+00 4.000e+00 ... 4.001e+03 4.002e+03 4.003e+03]
#  No of unique value: 3999
#
# address
#  ['060 Morning Avenue' '6 Meadow Vale Court' '0 Holy Cross Court' ...
#  '87 Crescent Oaks Alley' '8194 Lien Street' '320 Acker Drive']
#  No of unique value: 3996
#
# postcode
#  [2016. 2153. 4211. 2448. 3216. 2210. 2650. 2023. 3044. 4557. 3799. 2760.
#  2428. 3331. 3058. 2135. 2233. 2444. 4413. 4740. 3218. 4868. 4116. 2519.
#  2756. 2170. 4005. 4127. 2535. 4726. 4805. 2212. 2207. 3350. 3931. 4018.
#  4670. 2480. 3212. 2322. 3198. 2047. 4503. 2145. 4350. 2142. 2029. 2127.
#  4280. 2166. 2046. 2026. 2765. 2749. 2745. 3752. 2217. 2230. 3046. 3183.
#  2070. 2213. 4208. 2774. 4133. 4213. 4170. 2073. 3561. 2330. 3977. 2204.
#  2086. 2226. 2075. 2038. 2069. 2100. 3133. 3070. 2777. 2125. 2766. 2209.
#  2160. 2065. 2150. 2168. 4171. 2155. 2517. 2096. 2750. 2093. 3204. 4300.
#  3844. 4226. 3192. 2485. 2097. 4817. 2516. 3074. 4508. 4405. 2452. 2205.
# ...

# %%
df.dropna(inplace=True)

# %%
df1.dropna(subset=['last_name','DOB'],inplace=True)

# %%
df1.isnull().sum()/len(df1)*100
# Out:
# first_name                              0.000000
# last_name                               0.000000
# gender                                  0.000000
# past_3_years_bike_related_purchases     0.000000
# DOB                                     0.000000
# job_title                              10.691824
# job_industry_category                  16.666667
# wealth_segment                          0.000000
# deceased_indicator                      0.000000
# owns_car                                0.000000
# tenure                                  0.000000
# address                                 0.000000
# postcode                                0.000000
# state                                   0.000000
# country                                 0.000000
# property_valuation                      0.000000
# Rank                                    0.000000
# Value                                   0.000000
# dtype: float64

# %%
df1['job_title'].value_counts().head(10), df1['job_industry_category'].value_counts().head(10)
# Out:
# (Software Consultant               14
#  Environmental Tech                14
#  Associate Professor               14
#  Chief Design Engineer             12
#  Cost Accountant                   12
#  VP Marketing                      11
#  Social Worker                     11
#  Environmental Specialist          11
#  Payment Adjustment Coordinator    11
#  Assistant Manager                 11
#  Name: job_title, dtype: int64, Manufacturing         195
#  Financial Services    194
#  Health                149
#  Retail                 78
#  Property               62
#  IT                     35
#  Entertainment          34
#  Argiculture            25
#  Telecommunications     23
#  Name: job_industry_category, dtype: int64)

# %%
df1.isnull().sum()
# Out:
# first_name                               0
# last_name                                0
# gender                                   0
# past_3_years_bike_related_purchases      0
# DOB                                      0
# job_title                              102
# job_industry_category                  159
# wealth_segment                           0
# deceased_indicator                       0
# owns_car                                 0
# tenure                                   0
# address                                  0
# postcode                                 0
# state                                    0
# country                                  0
# property_valuation                       0
# Rank                                     0
# Value                                    0
# dtype: int64

# %%
df1_new=df1.drop(['first_name','last_name','deceased_indicator','address','country'],axis=1)

# %%
df1_new.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 954 entries, 1 to 1000
# Data columns (total 13 columns):
# gender                                 954 non-null object
# past_3_years_bike_related_purchases    954 non-null float64
# DOB                                    954 non-null datetime64[ns]
# job_title                              852 non-null object
# job_industry_category                  795 non-null object
# wealth_segment                         954 non-null object
# owns_car                               954 non-null object
# tenure                                 954 non-null float64
# postcode                               954 non-null float64
# state                                  954 non-null object
# property_valuation                     954 non-null float64
# Rank                                   954 non-null float64
# Value                                  954 non-null float64
# dtypes: datetime64[ns](1), float64(6), object(6)
# memory usage: 104.3+ KB

# %% [markdown]
# ## Treating missing values:

# %% [markdown]
# ##### DF missing value treatment

# %%
df_new=df.dropna()

# %%
df_new.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 19445 entries, 1 to 20000
# Data columns (total 13 columns):
# transaction_id             19445 non-null float64
# product_id                 19445 non-null float64
# customer_id                19445 non-null float64
# transaction_date           19445 non-null datetime64[ns]
# online_order               19445 non-null float64
# order_status               19445 non-null object
# brand                      19445 non-null object
# product_line               19445 non-null object
# product_class              19445 non-null object
# product_size               19445 non-null object
# list_price                 19445 non-null float64
# standard_cost              19445 non-null float64
# product_first_sold_date    19445 non-null float64
# dtypes: datetime64[ns](1), float64(7), object(5)
# memory usage: 2.1+ MB

# %% [markdown]
# ##### DF1_new missing value treatment

# %%
df1_new.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 954 entries, 1 to 1000
# Data columns (total 13 columns):
# gender                                 954 non-null object
# past_3_years_bike_related_purchases    954 non-null float64
# DOB                                    954 non-null datetime64[ns]
# job_title                              852 non-null object
# job_industry_category                  795 non-null object
# wealth_segment                         954 non-null object
# owns_car                               954 non-null object
# tenure                                 954 non-null float64
# postcode                               954 non-null float64
# state                                  954 non-null object
# property_valuation                     954 non-null float64
# Rank                                   954 non-null float64
# Value                                  954 non-null float64
# dtypes: datetime64[ns](1), float64(6), object(6)
# memory usage: 104.3+ KB

# %%
df1_new[['job_title','job_industry_category']].mode()
# Out:
#              job_title job_industry_category
# 0  Associate Professor         Manufacturing
# 1   Environmental Tech                   NaN
# 2  Software Consultant                   NaN

# %%
df1_new[df1_new['job_industry_category'].isnull()]
# Out:
#      gender  past_3_years_bike_related_purchases        DOB  \
# 23     Male                                 26.0 1998-02-05
# 24   Female                                  5.0 1977-12-17
# 34     Male                                 71.0 1981-09-22
# 37     Male                                 76.0 1968-03-25
# 44   Female                                 52.0 1966-09-18
# ..      ...                                  ...        ...
# 960  Female                                 62.0 1967-01-03
# 972  Female                                 43.0 1999-03-04
# 976    Male                                 63.0 1968-06-12
# 981  Female                                 71.0 1992-04-08
# 984  Female                                  5.0 1951-09-17
#
#                        job_title job_industry_category     wealth_segment  \
# 23              Quality Engineer                   NaN      Mass Customer
# 24    Quality Control Specialist                   NaN  Affluent Customer
# ...

# %%
df1_new[df1_new['wealth_segment']=='Mass Customer']['job_industry_category'].value_counts()
# Out:
# Financial Services    103
# Manufacturing          87
# Health                 73
# Retail                 45
# Property               36
# IT                     21
# Argiculture            18
# Entertainment          14
# Telecommunications      9
# Name: job_industry_category, dtype: int64

# %%
df1_new[df1_new['wealth_segment']=='High Net Worth']['job_industry_category'].value_counts()
# Out:
# Manufacturing         60
# Financial Services    41
# Health                40
# Entertainment         15
# Retail                13
# Property              13
# Telecommunications    10
# IT                     6
# Argiculture            2
# Name: job_industry_category, dtype: int64

# %%
df1_new[df1_new['wealth_segment']=='Affluent Customer']['job_industry_category'].value_counts()
# Out:
# Financial Services    50
# Manufacturing         48
# Health                36
# Retail                20
# Property              13
# IT                     8
# Argiculture            5
# Entertainment          5
# Telecommunications     4
# Name: job_industry_category, dtype: int64

# %%
df1_new[df1_new['wealth_segment']=='Affluent Customer']['job_industry_category'].isnull().value_counts()
# Out:
# False    189
# True      36
# Name: job_industry_category, dtype: int64

# %%
df1_new[df1_new['wealth_segment']=='High Net Worth']['job_industry_category'].isnull().value_counts()
# Out:
# False    200
# True      41
# Name: job_industry_category, dtype: int64

# %%
df1_new[df1_new['wealth_segment']=='Mass Customer']['job_industry_category'].isnull().value_counts()
# Out:
# False    406
# True      82
# Name: job_industry_category, dtype: int64

# %%
df1_new['job_industry_category']=np.where(((df1_new['job_industry_category'].isnull())&(df1_new['wealth_segment']=='Mass Customer')),'Financial Services',df1_new['job_industry_category'])

# %%
df1_new['job_industry_category']=np.where(((df1_new['job_industry_category'].isnull())&(df1_new['wealth_segment']=='High Net Worth')),'Manufacturing',df1_new['job_industry_category'])

# %%
df1_new['job_industry_category']=np.where(((df1_new['job_industry_category'].isnull())&(df1_new['wealth_segment']=='Affluent Customer')),'Financial Services',df1_new['job_industry_category'])

# %%
df1_new[df1_new['wealth_segment']=='Mass Customer']['job_title'].value_counts().head(8)
# Out:
# Associate Professor     11
# Nurse Practicioner       8
# Financial Analyst        7
# VP Sales                 7
# Product Engineer         7
# Recruiting Manager       7
# VP Marketing             7
# Compensation Analyst     6
# Name: job_title, dtype: int64

# %%
df1_new[df1_new['wealth_segment']=='High Net Worth']['job_title'].value_counts().head(8)
# Out:
# Help Desk Operator                      7
# Librarian                               5
# Chemical Engineer                       5
# Marketing Manager                       5
# Social Worker                           5
# Nurse                                   4
# Human Resources Manager                 4
# Business Systems Development Analyst    4
# Name: job_title, dtype: int64

# %%
df1_new[df1_new['wealth_segment']=='Affluent Customer']['job_title'].value_counts().head(8)
# Out:
# Software Consultant         6
# Environmental Tech          6
# Senior Sales Associate      5
# Geologist III               4
# Environmental Specialist    4
# Structural Engineer         4
# Financial Advisor           4
# Junior Executive            4
# Name: job_title, dtype: int64

# %%
df1_new[df1_new['wealth_segment']=='Mass Customer']['job_title'].isnull().sum()
# Out:
# 58

# %%
df1_new[df1_new['wealth_segment']=='High Net Worth']['job_title'].isnull().sum()
# Out:
# 24

# %%
df1_new[df1_new['wealth_segment']=='Affluent Customer']['job_title'].isnull().sum()
# Out:
# 20

# %%
df1_new['job_title']=np.where(((df1_new['job_title'].isnull())&(df1_new['wealth_segment']=='Mass Customer')),'Associate Professor',df1_new['job_title'])

# %%
df1_new['job_title']=np.where(((df1_new['job_title'].isnull())&(df1_new['wealth_segment']=='High Net Worth')),'Help Desk Operator',df1_new['job_title'])

# %%
df1_new['job_title']=np.where(((df1_new['job_title'].isnull())&(df1_new['wealth_segment']=='Affluent Customer')),'Software Consultant',df1_new['job_title'])

# %%
df1_new.isnull().sum()
# Out:
# gender                                 0
# past_3_years_bike_related_purchases    0
# DOB                                    0
# job_title                              0
# job_industry_category                  0
# wealth_segment                         0
# owns_car                               0
# tenure                                 0
# postcode                               0
# state                                  0
# property_valuation                     0
# Rank                                   0
# Value                                  0
# dtype: int64

# %% [markdown]
# ##### DF2 missing value treatment

# %%
df2_new=df2.drop(['first_name','last_name','default'],axis=1)

# %% [markdown]
# ###### JOB TITLE

# %%
df2_new['job_title'].isnull().sum()
# Out:
# 506

# %%
df2_new[df2_new['wealth_segment']=='Mass Customer']['job_title'].isnull().sum()
# Out:
# 260

# %%
df2_new[df2_new['wealth_segment']=='High Net Worth']['job_title'].isnull().sum()
# Out:
# 130

# %%
df2_new[df2_new['wealth_segment']=='Affluent Customer']['job_title'].isnull().sum()
# Out:
# 116

# %%
df2_new[df2_new['wealth_segment']=='Mass Customer']['job_title'].value_counts().head(10)
# Out:
# Tax Accountant          26
# Social Worker           24
# Help Desk Technician    24
# Recruiting Manager      23
# Junior Executive        22
# Executive Secretary     22
# Chemical Engineer       22
# Structural Engineer     22
# Legal Assistant         22
# Internal Auditor        21
# Name: job_title, dtype: int64

# %%
df2_new[df2_new['wealth_segment']=='High Net Worth']['job_title'].value_counts().head(10)
# Out:
# Dental Hygienist         14
# Cost Accountant          13
# Structural Engineer      13
# VP Product Management    12
# Senior Developer         12
# Staff Scientist          12
# Electrical Engineer      12
# Teacher                  11
# Technical Writer         11
# Associate Professor      11
# Name: job_title, dtype: int64

# %%
df2_new[df2_new['wealth_segment']=='Affluent Customer']['job_title'].value_counts().head(8)
# Out:
# Business Systems Development Analyst    25
# General Manager                         14
# VP Sales                                13
# Social Worker                           12
# Recruiting Manager                      12
# Product Engineer                        12
# Senior Editor                           12
# Nurse                                   12
# Name: job_title, dtype: int64

# %%
df2_new['job_title']=np.where(((df2_new['job_title'].isnull())&(df2_new['wealth_segment']=='Mass Customer')),'Tax Accountant',df2_new['job_title'])

# %%
df2_new['job_title']=np.where(((df2_new['job_title'].isnull())&(df2_new['wealth_segment']=='High Net Worth')),'Dental Hygienist',df2_new['job_title'])

# %%
df2_new['job_title']=np.where(((df2_new['job_title'].isnull())&(df2_new['wealth_segment']=='Affluent Customer')),'Business Systems Development Analyst',df2_new['job_title'])

# %%
df2_new['job_title'].isnull().sum()
# Out:
# 0

# %% [markdown]
# ###### JOB INDUSTRY CATEGORY

# %%
df2_new['job_industry_category'].isnull().sum()
# Out:
# 656

# %%
df2_new[df2_new['wealth_segment']=='Mass Customer']['job_industry_category'].isnull().sum()
# Out:
# 318

# %%
df2_new[df2_new['wealth_segment']=='High Net Worth']['job_industry_category'].isnull().sum()
# Out:
# 170

# %%
df2_new[df2_new['wealth_segment']=='Affluent Customer']['job_industry_category'].isnull().sum()
# Out:
# 168

# %%
df2_new[df2_new['wealth_segment']=='Mass Customer']['job_industry_category'].value_counts().head(10)
# Out:
# Manufacturing         404
# Financial Services    382
# Health                313
# Retail                178
# Property              136
# IT                    109
# Entertainment          71
# Argiculture            54
# Telecommunications     35
# Name: job_industry_category, dtype: int64

# %%
df2_new[df2_new['wealth_segment']=='High Net Worth']['job_industry_category'].value_counts().head(10)
# Out:
# Financial Services    204
# Manufacturing         171
# Health                155
# Retail                 92
# Property               77
# IT                     61
# Argiculture            37
# Entertainment          33
# Telecommunications     21
# Name: job_industry_category, dtype: int64

# %%
df2_new[df2_new['wealth_segment']=='Affluent Customer']['job_industry_category'].value_counts().head(8)
# Out:
# Manufacturing         224
# Financial Services    188
# Health                134
# Retail                 88
# Property               54
# IT                     53
# Entertainment          32
# Argiculture            22
# Name: job_industry_category, dtype: int64

# %%
df2_new['job_industry_category']=np.where(((df2_new['job_industry_category'].isnull())&(df2_new['wealth_segment']=='Mass Customer')),'Tax Accountant',df2_new['job_industry_category'])

# %%
df2_new['job_industry_category']=np.where(((df2_new['job_industry_category'].isnull())&(df2_new['wealth_segment']=='High Net Worth')),'Dental Hygienist',df2_new['job_industry_category'])

# %%
df2_new['job_industry_category']=np.where(((df2_new['job_industry_category'].isnull())&(df2_new['wealth_segment']=='Affluent Customer')),'Business Systems Development Analyst',df2_new['job_industry_category'])

# %%
df2_new['job_industry_category'].isnull().sum()
# Out:
# 0

# %%
# Here checked the df2 dataframe

# %%
df2.columns
# Out:
# Index(['customer_id', 'first_name', 'last_name', 'gender',
#        'past_3_years_bike_related_purchases', 'DOB', 'job_title',
#        'job_industry_category', 'wealth_segment', 'deceased_indicator',
#        'default', 'owns_car', 'tenure'],
#       dtype='object')

# %%
col=['customer_id', 'first_name', 'last_name', 'gender',
       'past_3_years_bike_related_purchases', 'DOB', 'job_title',
       'job_industry_category', 'wealth_segment', 'deceased_indicator',
       'default', 'owns_car', 'tenure']
for i in col:
        print(i,'\n',df2[i].unique(),'\n','No of unique value:',df2[i].nunique(),'\n')
# Out:
# customer_id
#  [1.000e+00 2.000e+00 3.000e+00 ... 3.998e+03 3.999e+03 4.000e+03]
#  No of unique value: 4000
#
# first_name
#  ['Laraine' 'Eli' 'Arlin' ... 'Stephie' 'Rusty' 'Sarene']
#  No of unique value: 3139
#
# last_name
#  ['Medendorp' 'Bockman' 'Dearle' ... 'Halgarth' 'Woolley' 'Oldland']
#  No of unique value: 3725
#
# gender
#  ['F' 'Male' 'Female' 'U' 'Femal' 'M']
#  No of unique value: 6
#
# past_3_years_bike_related_purchases
#  [93. 81. 61. 33. 56. 35.  6. 31. 97. 49. 99. 58. 38. 85. 91. 57. 79. 76.
#  72. 74. 43. 55. 12. 37.  5. 62. 18.  3. 17. 44. 59. 40. 46. 64. 24. 63.
#  98. 51. 68. 22.  2. 48. 87. 26. 60. 47. 73. 21. 67. 16. 78. 30. 94. 28.
#  20. 11.  1. 75. 41. 69. 19. 80. 83. 25. 54.  4. 23. 65. 88. 10. 77.  9.
#  82. 27. 53. 32. 34. 71. 36. 90. 95.  8. 39.  7. 42. 13. 45. 50. 14. 89.
#  84. 96. 70. 66.  0. 15. 86. 92. 29. 52.]
#  No of unique value: 100
#
# DOB
#  ['1953-10-12T00:00:00.000000000' '1980-12-16T00:00:00.000000000'
# ...

# %%
df2_new['gender'].replace( to_replace=['F'],value='Female',inplace=True)

# %%
df2_new['gender'].replace(
    to_replace=['M'],
    value='Male',
    inplace=True
)

# %%
df2_new['gender'].replace(
    to_replace=['Femal'],
    value='Female',
    inplace=True
)

# %%
df2_new=df2_new[df2_new['gender']!='U']

# %%
df2_new.head()
# Out:
#    customer_id  gender  past_3_years_bike_related_purchases        DOB  \
# 1          1.0  Female                                 93.0 1953-10-12
# 2          2.0    Male                                 81.0 1980-12-16
# 3          3.0    Male                                 61.0 1954-01-20
# 4          4.0    Male                                 33.0 1961-10-03
# 5          5.0  Female                                 56.0 1977-05-13
#
#                 job_title                 job_industry_category  \
# 1     Executive Secretary                                Health
# 2  Administrative Officer                    Financial Services
# 3      Recruiting Manager                              Property
# 4          Tax Accountant                                    IT
# 5           Senior Editor  Business Systems Development Analyst
#
#       wealth_segment deceased_indicator owns_car  tenure
# 1      Mass Customer                  N      Yes    11.0
# ...

# %%
# Here checked 
df1_new['gender']=='U'
# Out:
# 1       False
# 2       False
# 3       False
# 4       False
# 5       False
#         ...
# 996     False
# 997     False
# 998     False
# 999     False
# 1000    False
# Name: gender, Length: 954, dtype: bool

# %%
df1.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 954 entries, 1 to 1000
# Data columns (total 18 columns):
# first_name                             954 non-null object
# last_name                              954 non-null object
# gender                                 954 non-null object
# past_3_years_bike_related_purchases    954 non-null float64
# DOB                                    954 non-null datetime64[ns]
# job_title                              852 non-null object
# job_industry_category                  795 non-null object
# wealth_segment                         954 non-null object
# deceased_indicator                     954 non-null object
# owns_car                               954 non-null object
# tenure                                 954 non-null float64
# address                                954 non-null object
# postcode                               954 non-null float64
# state                                  954 non-null object
# ...

# %% [markdown]
# ### Categorical Univariate Analysis

# %%
plt.figure(figsize=(10,5))
ax=sns.countplot(data=df_new,x='product_class',order=df_new['product_class'].value_counts().index)
total = float(len(df))
for p in ax.patches:
    height = p.get_height()
    ax.text(p.get_x()+p.get_width()/2.,
            height + 3,
            '{:1.2f}%'.format((height/total)*100),
            ha="center")
plt.show()

# %%
plt.figure(figsize=(10,5))
ax=sns.countplot(data=df_new,x='brand',order=df_new['brand'].value_counts().index)
total = float(len(df))
for p in ax.patches:
    height = p.get_height()
    ax.text(p.get_x()+p.get_width()/2.,
            height + 3,
            '{:1.2f}%'.format((height/total)*100),
            ha="center")
plt.show()

# %%
plt.figure(figsize=(10,5))
ax=sns.countplot(data=df_new,x='product_line',order=df_new['product_line'].value_counts().index)
total = float(len(df))
for p in ax.patches:
    height = p.get_height()
    ax.text(p.get_x()+p.get_width()/2.,
            height + 3,
            '{:1.2f}%'.format((height/total)*100),
            ha="center")
plt.show()

# %%
plt.figure(figsize=(10,5))
ax=sns.countplot(data=df_new,x='product_size',order=df_new['product_size'].value_counts().index)
total = float(len(df))
for p in ax.patches:
    height = p.get_height()
    ax.text(p.get_x()+p.get_width()/2.,
            height + 3,
            '{:1.2f}%'.format((height/total)*100),
            ha="center")
plt.show()

# %% [markdown]
# Medium size product is more preferable colmpare to large and small

# %%
df
# Out:
#        transaction_id  product_id  customer_id transaction_date  online_order  \
# 1                 1.0         2.0       2950.0       2017-02-25           0.0
# 2                 2.0         3.0       3120.0       2017-05-21           1.0
# 3                 3.0        37.0        402.0       2017-10-16           0.0
# 4                 4.0        88.0       3135.0       2017-08-31           0.0
# 5                 5.0        78.0        787.0       2017-10-01           1.0
# ...               ...         ...          ...              ...           ...
# 19996         19996.0        51.0       1018.0       2017-06-24           1.0
# 19997         19997.0        41.0        127.0       2017-11-09           1.0
# 19998         19998.0        87.0       2284.0       2017-04-14           1.0
# 19999         19999.0         6.0       2764.0       2017-07-03           0.0
# 20000         20000.0        11.0       1144.0       2017-09-22           1.0
#
# ...

# %%
plt.figure(figsize=(10,5))
ax=sns.countplot(data=df_new,x='brand',order=df_new['brand'].value_counts().index)
total = float(len(df))
for p in ax.patches:
    height = p.get_height()
    ax.text(p.get_x()+p.get_width()/1.5,
            height + 3,
            '{:1.2f}%'.format((height/total)*100),
            ha="center")
plt.show()

# %% [markdown]
# solex is the top selling brand

# %%
plt.figure(figsize=(10,5))
ax=sns.countplot(data=df_new,x='product_line',order=df_new['product_line'].value_counts().index)
total = float(len(df))
for p in ax.patches:
    height = p.get_height()
    ax.text(p.get_x()+p.get_width()/2.,
            height + 3,
            '{:1.2f}%'.format((height/total)*100),
            ha="center")
plt.show()

# %%
plt.figure(figsize=(10,5))
ax=sns.countplot(data=df_new,x='online_order',order=df_new['online_order'].value_counts().index)
total = float(len(df))
for p in ax.patches:
    height = p.get_height()
    ax.text(p.get_x()+p.get_width()/2.,
            height + 3,
            '{:1.2f}%'.format((height/total)*100),
            ha="center")
plt.show()

# %% [markdown]
# companies transation does not depend on the mode of order

# %%
plt.figure(figsize=(10,5))
ax=sns.countplot(data=df_new,x='product_line',order=df_new['product_line'].value_counts().index)
total = float(len(df))
for p in ax.patches:
    height = p.get_height()
    ax.text(p.get_x()+p.get_width()/2.,
            height + 3,
            '{:1.2f}%'.format((height/total)*100),
            ha="center")
plt.show()

# %%
plt.figure(figsize=(10,5))
ax=sns.countplot(data=df_new,x='product_class',order=df_new['product_class'].value_counts().index)
total = float(len(df))
for p in ax.patches:
    height = p.get_height()
    ax.text(p.get_x()+p.get_width()/2.,
            height + 3,
            '{:1.2f}%'.format((height/total)*100),
            ha="center")
plt.show()

# %% [markdown]
# Medium class product is more preferable

# %%
plt.figure(figsize=(10,5))
ax=sns.countplot(data=df_new,x='order_status',order=df_new['order_status'].value_counts().index)
total = float(len(df))
for p in ax.patches:
    height = p.get_height()
    ax.text(p.get_x()+p.get_width()/2.,
            height + 3,
            '{:1.2f}%'.format((height/total)*100),
            ha="center")
plt.show()

# %% [markdown]
# company has good reputation in market and it has good brand value that's why company is getting more order

# %%
#Here 
df_new=df_new.set_index(['transaction_date'])

# %%
# Here i plot 
df_new.plot(grid=True,figsize=(10,5))
plt.show()

# %%
df2_new
# Out:
#       customer_id  gender  past_3_years_bike_related_purchases        DOB  \
# 1             1.0  Female                                 93.0 1953-10-12
# 2             2.0    Male                                 81.0 1980-12-16
# 3             3.0    Male                                 61.0 1954-01-20
# 4             4.0    Male                                 33.0 1961-10-03
# 5             5.0  Female                                 56.0 1977-05-13
# ...           ...     ...                                  ...        ...
# 3995       3995.0    Male                                 93.0 1975-12-12
# 3996       3996.0  Female                                  8.0 1975-08-09
# 3997       3997.0  Female                                 87.0 2001-07-13
# 3999       3999.0    Male                                 11.0 1973-10-24
# 4000       4000.0    Male                                 76.0 1991-11-05
#
#                                  job_title  \
# ...

# %%
plt.figure(figsize=(10,5))
ax=sns.countplot(data=df2_new,x='gender',order=df2_new['gender'].value_counts().index)
total = float(len(df2_new))
for p in ax.patches:
    height = p.get_height()
    ax.text(p.get_x()+p.get_width()/2.,
            height + 3,
            '{:1.2f}%'.format((height/total)*100),
            ha="center")
plt.show()

# %%
plt.figure(figsize=(10,5))
ax=sns.countplot(data=df2_new,x='wealth_segment',order=df2_new['wealth_segment'].value_counts().index)
total = float(len(df2_new))
for p in ax.patches:
    height = p.get_height()
    ax.text(p.get_x()+p.get_width()/2.,
            height + 3,
            '{:1.2f}%'.format((height/total)*100),
            ha="center")
plt.show()

# %%
plt.figure(figsize=(10,5))
ax=sns.countplot(data=df2_new,x='owns_car',order=df2_new['owns_car'].value_counts().index)
total = float(len(df2_new))
for p in ax.patches:
    height = p.get_height()
    ax.text(p.get_x()+p.get_width()/2.,
            height + 3,
            '{:1.2f}%'.format((height/total)*100),
            ha="center")
plt.show()

# %%
plt.figure(figsize=(10,5))
ax=sns.countplot(data=df2_new,x='deceased_indicator',order=df2_new['deceased_indicator'].value_counts().index)
total = float(len(df2_new))
for p in ax.patches:
    height = p.get_height()
    ax.text(p.get_x()+p.get_width()/2.,
            height + 3,
            '{:1.2f}%'.format((height/total)*100),
            ha="center")
plt.show()

# %%
sns.distplot(df2_new['tenure'],hist=True)
plt.show()

# %%
# Here checked the mean
sns.distplot(df2_new['tenure'],hist=False)
plt.axvline(df2_new['tenure'].mean(),color='r')
plt.show()

# %%
sns.distplot(df2_new['past_3_years_bike_related_purchases'],hist=True)
plt.show()

# %% [markdown]
# ## Univariate Analysis

# %%
plt.figure(figsize=(10,5))
sns.scatterplot(x="past_3_years_bike_related_purchases", y="tenure", data=df2_new)

# %%
plt.figure(figsize=(10,5))
ax = sns.countplot(data=df2_new,x='wealth_segment',hue ='gender',order=df2_new['wealth_segment'].value_counts().index)
total = float(len(df2_new))
for p in ax.patches:
    height = p.get_height()
    ax.text(p.get_x()+p.get_width()/2,
            height + 3,
            '{:1.2f}%'.format((height/total)*100),
            ha="center")
plt.title('Wealth segement of customer according to gender')
plt.show()

# %% [markdown]
# Majority of mass customer is belongs to the Female

# %%
plt.figure(figsize=(15,5))
ax = sns.countplot(data=df2_new,x='owns_car',hue ='gender',order=df2_new['owns_car'].value_counts().index)
total = float(len(df2_new))
for p in ax.patches:
    height = p.get_height()
    ax.text(p.get_x()+p.get_width()/2,
            height + 3,
            '{:1.2f}%'.format((height/total)*100),
            ha="center")
#plt.title('Wealth segement of customer according to gender')
plt.show()

# %%
plt.figure(figsize=(15,5))
ax = sns.barplot(data=df2_new,x='owns_car',y='past_3_years_bike_related_purchases')
total = float(len(df2_new))
for p in ax.patches:
    height = p.get_height()
    ax.text(p.get_x()+p.get_width()/2,
            height + 3,
            '{:1.2f}%'.format((height/total)*100),
            ha="center")
#plt.title('Wealth segement of customer according to gender')
plt.show()

# %%
sns.boxplot(x="owns_car", y="past_3_years_bike_related_purchases", data=df2_new)

# %%
df3
# Out:
#       customer_id                    address  postcode            state  \
# 1             1.0         060 Morning Avenue    2016.0  New South Wales
# 2             2.0        6 Meadow Vale Court    2153.0  New South Wales
# 3             4.0         0 Holy Cross Court    4211.0              QLD
# 4             5.0        17979 Del Mar Point    2448.0  New South Wales
# 5             6.0           9 Oakridge Court    3216.0              VIC
# ...           ...                        ...       ...              ...
# 3995       3999.0            1482 Hauk Trail    3064.0              VIC
# 3996       4000.0  57042 Village Green Point    4511.0              QLD
# 3997       4001.0     87 Crescent Oaks Alley    2756.0              NSW
# 3998       4002.0           8194 Lien Street    4032.0              QLD
# 3999       4003.0            320 Acker Drive    2251.0              NSW
#
#         country  property_valuation
# 1     Australia                10.0
# ...

# %%
plt.figure(figsize=(10,5))
ax=sns.countplot(data=df3,x='state',order=df3['state'].value_counts().index)
total = len(df3)
for p in ax.patches:
    height = p.get_height()
    ax.text(p.get_x()+p.get_width()/2.,
            height + 3,
            '{:1.2f}%'.format((height/total)*100),
            ha="center")
plt.title('Which state in Australia got what percentage of customer')
plt.show()

# %%
plt.figure(figsize=(10,5))
ax=sns.countplot(data=df3,x='property_valuation',order=df3['property_valuation'].value_counts().index)
total = len(df3)
for p in ax.patches:
    height = p.get_height()
    ax.text(p.get_x()+p.get_width()/2.,
            height + 3,
            '{:1.2f}%'.format((height/total)*100),
            ha="center")
#plt.title('Which state in Australia got what percentage of customer')
plt.show()

# %% [markdown]
# Here i checked about the property valuation so we can see that (9th number rating has highest of the property valuation)

# %%
# Merge two data file
df_customer = pd.merge(df2_new,df3,how = 'inner')
df_customer.head()
# Out:
#    customer_id  gender  past_3_years_bike_related_purchases        DOB  \
# 0          1.0  Female                                 93.0 1953-10-12
# 1          2.0    Male                                 81.0 1980-12-16
# 2          4.0    Male                                 33.0 1961-10-03
# 3          5.0  Female                                 56.0 1977-05-13
# 4          6.0    Male                                 35.0 1966-09-16
#
#                 job_title                 job_industry_category  \
# 0     Executive Secretary                                Health
# 1  Administrative Officer                    Financial Services
# 2          Tax Accountant                                    IT
# 3           Senior Editor  Business Systems Development Analyst
# 4        Dental Hygienist                                Retail
#
#       wealth_segment deceased_indicator owns_car  tenure              address  \
# ...

# %%
plt.figure(figsize=(17,5))
ax = sns.countplot(data=df_customer,x='wealth_segment',hue ='property_valuation',order=df_customer['wealth_segment'].value_counts().index)
#total = float(len(df_customer))
#for p in ax.patches:
 #   height = p.get_height()
  #  ax.text(p.get_x()+p.get_width()/2,
   #         height + 3,
    #        '{:1.2f}%'.format((height/total)*100),
     #       ha="center")
#plt.title('Wealth segement of customer according to gender')
plt.show()

# %% [markdown]
# Here i checked about the property valuation which is giving the informatioon about the welth_segment column

# %%
#Here extracting data from dataframe
df_prop8=df_customer.loc[df_customer['property_valuation']==8.0]
df_prop8
# Out:
#       customer_id  gender  past_3_years_bike_related_purchases        DOB  \
# 8            11.0    Male                                 99.0 1954-04-30
# 11           14.0  Female                                 85.0 1983-03-25
# 17           20.0    Male                                 72.0 1980-08-13
# 30           36.0  Female                                 33.0 1977-11-09
# 34           40.0  Female                                 91.0 1981-10-27
# ...           ...     ...                                  ...        ...
# 3875       3967.0  Female                                 90.0 1978-04-18
# 3879       3971.0  Female                                  2.0 1979-01-14
# 3882       3974.0  Female                                 82.0 1961-02-11
# 3887       3979.0    Male                                 67.0 1974-07-13
# 3898       3990.0    Male                                 99.0 1998-03-05
#
#                            job_title                 job_industry_category  \
# ...

# %%
#Here extracting data from dataframe
df_prop9=df_customer.loc[df_customer['property_valuation']==9.0]
df_prop9.head()
# Out:
#     customer_id  gender  past_3_years_bike_related_purchases        DOB  \
# 2           4.0    Male                                 33.0 1961-10-03
# 4           6.0    Male                                 35.0 1966-09-16
# 5           7.0  Female                                  6.0 1976-02-23
# 12         15.0    Male                                 91.0 2000-07-13
# 14         17.0    Male                                 57.0 1962-03-19
#
#                                job_title  \
# 2                         Tax Accountant
# 4                       Dental Hygienist
# 5   Business Systems Development Analyst
# 12                      Junior Executive
# 14                       Sales Associate
#
#                    job_industry_category     wealth_segment  \
# 2                                     IT      Mass Customer
# 4                                 Retail     High Net Worth
# 5                     Financial Services  Affluent Customer
# ...

# %%
#Here we can not join & merge becaus nothing in common so that's why we can not add 
# so we use concat for adding the dataframe
df_prop89=pd.concat([df_prop8, df_prop9], ignore_index=True)
df_prop89.head()
# Out:
#    customer_id  gender  past_3_years_bike_related_purchases        DOB  \
# 0         11.0    Male                                 99.0 1954-04-30
# 1         14.0  Female                                 85.0 1983-03-25
# 2         20.0    Male                                 72.0 1980-08-13
# 3         36.0  Female                                 33.0 1977-11-09
# 4         40.0  Female                                 91.0 1981-10-27
#
#                         job_title                 job_industry_category  \
# 0                  Tax Accountant                              Property
# 1               Account Executive                    Financial Services
# 2                 Project Manager                         Manufacturing
# 3              VP Quality Control  Business Systems Development Analyst
# 4  Payment Adjustment Coordinator                         Manufacturing
#
#       wealth_segment deceased_indicator owns_car  tenure  \
# ...

# %%
#using here crosstab between job_title and job_industry_category by using df_prop89 
#pd.crosstab(index=df_prop89['job_title'],columns=df_prop89['job_industry_category'])

# %%
#important for understanding
#df_prop89.groupby('job_title')['job_industry_category'].count()

# %%
#important for understanding
#print(df_prop89.groupby(['job_industry_category','job_title',])['property_valuation'].count())

# %%
#df4 = pd.DataFrame(df_prop89.groupby(['job_industry_category','job_title',])['property_valuation'].count())
#df4

# %%
#here i used small bracket used for groupby and and jiske sath karna h oosko square bracketa
a=df_prop89.groupby(['job_industry_category','job_title'])['property_valuation'].count().to_frame(name='count').reset_index()

# %%
a.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 628 entries, 0 to 627
# Data columns (total 3 columns):
# job_industry_category    628 non-null object
# job_title                628 non-null object
# count                    628 non-null int64
# dtypes: int64(1), object(2)
# memory usage: 14.8+ KB

# %%
a.head()
# Out:
#   job_industry_category                     job_title  count
# 0           Argiculture    Administrative Assistant I      1
# 1           Argiculture  Administrative Assistant III      1
# 2           Argiculture   Administrative Assistant IV      1
# 3           Argiculture           Assistant Professor      2
# 4           Argiculture             Biostatistician I      1
